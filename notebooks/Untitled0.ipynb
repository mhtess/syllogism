# %%
using Gadfly
# Out:
# Warning: New definition
#     cat_aes_var!(AbstractArray
# {T,N},AbstractArray{U<:Union(DataType,Function),N}) at /Users/mht/.julia/v0.3/Gadfly/src/aesthetics.jl:262
# is ambiguous with:
#     cat_aes_var!(AbstractArray{T<:Union(DataType,Function),N},AbstractArray{U,N}) at /Users/mht/.julia/v0.3/Gadfly/src/aesthetics.jl:257.
# To fix, define
#     cat_aes_var!(AbstractArray{_<:Union(DataType,Function),N},AbstractArray{_<:Union(DataType,Function),N})
# before the new definition.
# Warning: New definition
#     cat_aes_var!(AbstractArray{T,N},AbstractArray{U<:Union(DataType,Function),N}) at /Users/mht/.julia/v0.3/Gadfly/src/aesthetics.jl:262
# is ambiguous with:
#     cat_aes_var!(AbstractArray{T,N},AbstractArray{T,N}) at /Users/mht/.julia/v0.3/Gadfly/src/aesthetics.jl:249.
# To fix, define
#     cat_aes_var!(AbstractArray{T,N},AbstractArray{_<:Union(DataType,Function),N})
# before the new definition.

# %%
plot(x=rand(10), y=rand(10))
# Out:
# Plot(...)

# %%
plot(x=1:10, y=2.^rand(10),
     Scale.y_sqrt, Geom.point, Geom.smooth,
     Guide.xlabel("Stimulus"), Guide.ylabel("Response"), Guide.title("Dog Training"))
# Out:
# Plot(...)

# %%
using RDatasets

# %%
plot(dataset("datasets", "iris"), x="SepalLength", y="SepalWidth", Geom.point)
# Out:
# Plot(...)

# %%
plot(dataset("car", "SLID"), x="Wages", color="Language", Geom.histogram)
# Out:
# Plot(...)
